# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
weather = pd.read_csv('weatherHistory.csv')
weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
weather.drop('Loud Cover',axis=1,inplace=True)

# %%
weather.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
weather['Precip Type'].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
# Replacing the missing values with forward fill method
weather = weather.fillna(method='ffill')
weather.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# ...

# %%
# Time is converting to UTC format
weather['Formatted Date'] = pd.to_datetime(weather['Formatted Date'], utc=True)
weather['Formatted Date'].head()
# Out:
# 0   2006-03-31 22:00:00+00:00
# 1   2006-03-31 23:00:00+00:00
# 2   2006-04-01 00:00:00+00:00
# 3   2006-04-01 01:00:00+00:00
# 4   2006-04-01 02:00:00+00:00
# Name: Formatted Date, dtype: datetime64[ns, UTC]

# %%
# Dataframe index set to 'Formatted Date'
weather = weather.set_index('Formatted Date')
weather.head(2)
# Out:
#                                  Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
#
#                            Apparent Temperature (C)  Humidity  \
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
#
#                            Wind Speed (km/h)  Wind Bearing (degrees)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00            14.1197                   251.0
# 2006-03-31 23:00:00+00:00            14.2646                   259.0
#
#                            Visibility (km)  Pressure (millibars)  \
# Formatted Date
# 2006-03-31 22:00:00+00:00          15.8263               1015.13
# 2006-03-31 23:00:00+00:00          15.8263               1015.63
#
#                                                Daily Summary
# Formatted Date
# ...

# %% [markdown]
# *Exploratory Data analysis*

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=weather.corr(),annot=True)
plt.show()

# %%
weather_monthly = weather.resample('MS').mean()
weather_monthly.head()
# Out:
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-01 00:00:00+00:00         0.577778                 -4.050000
# 2006-01-01 00:00:00+00:00        -1.677942                 -4.173708
# 2006-02-01 00:00:00+00:00        -0.065394                 -2.990716
# 2006-03-01 00:00:00+00:00         4.559274                  1.969780
# 2006-04-01 00:00:00+00:00        12.635031                 12.098827
#
#                            Humidity  Wind Speed (km/h)  \
# Formatted Date
# 2005-12-01 00:00:00+00:00  0.890000          17.114300
# 2006-01-01 00:00:00+00:00  0.834610           8.894211
# 2006-02-01 00:00:00+00:00  0.843467          10.957008
# 2006-03-01 00:00:00+00:00  0.778737          14.421488
# 2006-04-01 00:00:00+00:00  0.728625          10.930670
#
#                            Wind Bearing (degrees)  Visibility (km)  \
# Formatted Date
# 2005-12-01 00:00:00+00:00              140.000000         9.982000
# ...

# %%
weather_monthly.drop(['Temperature (C)','Wind Speed (km/h)','Wind Bearing (degrees)','Visibility (km)','Pressure (millibars)'],axis=1,inplace=True)

# %%
weather_monthly.head()
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625

# %%
def label_color(month):
    if month == 1:
        return 'January','blue'
    elif month == 2:
        return 'February','green'
    elif month == 3:
        return 'March','orange'
    elif month == 4:
        return 'April','yellow'
    elif month == 5:
        return 'May','red'
    elif month == 6:
        return 'June','violet'
    elif month == 7:
        return 'July','purple'
    elif month == 8:
        return 'August','black'
    elif month == 9:
        return 'September','brown'
    elif month == 10:
        return 'October','darkblue'
    elif month == 11:
        return 'November','grey'
    else:
        return 'December','pink'

def plot_month(month, data):
    label, color = label_color(month)
    mdata = data[data.index.month == month]
    sns.lineplot(data=mdata,
                 label=label,
                 color=color,
                 marker='o')
    
def sns_plot(title, data):
    plt.figure(figsize=(14,8))
    plt.title(title)
    plt.xlabel('YEAR')
    for i in range(1,13):
        plot_month(i,data)
    plt.show()

# %%
title = 'Plot of Apparent Temperature (C) - Month-wise' 
sns_plot(title, weather_monthly.iloc[:,0])

# %%
title = 'Plot of Humidity- Month-wise' 
sns_plot(title, weather_monthly.iloc[:,1])

# %%
sns.distplot(weather_monthly['Apparent Temperature (C)'])
plt.show()
sns.distplot(weather_monthly['Humidity'])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Variation of Apparent Temperature and Humidity')
sns.lineplot(data=weather_monthly)
plt.show()

# %%
#Humidity and Apparent Temperature monthwise 
def line_plot(data):
    for i in range(1,13):
        mon = data[data.index.month==i]
        plt.figure(figsize=(10,3))
        plt.plot(mon['Humidity'],label= 'Humidity',color='blue',linestyle='dashed')
        plt.plot(mon['Apparent Temperature (C)'],label = 'Apparendt Temperature (C)',color='red')
        plt.title('Apparante Temperature and Humidity variation Monthwise')
        plt.legend(loc=0)

# %%
line_plot(weather_monthly)

# %%
sns.distplot(weather_monthly['Apparent Temperature (C)'],bins=50)

# %%
sns.distplot(weather_monthly['Humidity'],bins=50)

# %%
from scipy.stats import ttest_rel
data1 = weather_monthly['Apparent Temperature (C)']
data2 = weather_monthly['Humidity']
test = ttest_rel(data1,data2)
stat , p = test[0],test[1]
print('stat=%.3f, p=%.3f' % (stat, p))
# Out:
# stat=12.404, p=0.000

# %%
if p > 0.05:
    print('Accept Null Hypothesis')
else:
    print('Reject Null Hypothesis')
# Out:
# Reject Null Hypothesis
